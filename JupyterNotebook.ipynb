# %%
print("Hello World") #hello
# Out:
# Hello World

# %% [markdown]
# <a href=https://www.cognitiveclass.ai/>

# %% [markdown]
# | header | header |col3 |
# | ------ | ------ |------|
# | cell | cell |
# | row2 |row2col2|row2col3|

# %% [markdown]
# <a href="www.google.com" >Link </a>

# %%
import matplotlib.pyplot as plt
a=[1,2]
b=[1,4]
plt.plot(a,b)
plt.show()
